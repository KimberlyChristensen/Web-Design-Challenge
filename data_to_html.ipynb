# %%
import pandas as pd
df = pd.read_csv('Resources/weather_data.csv')

# %%
df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         Chuy -33.6971  -53.4616     77.14        68           2        7.61
# 1      Rikitea -23.1203 -134.9692     79.88        67          97        6.49
# 2  Yellowknife  62.4560 -114.3525    -14.01        76           1        9.22
# 3      Khuzdar  27.7384   66.6434     47.61        36           4        2.48
# 4    Upernavik  72.7868  -56.1549     -7.31        82          86       11.95
#
#   Country        Date
# 0      UY  1611955477
# 1      PF  1611955257
# 2      CA  1611955477
# 3      PK  1611955477
# 4      GL  1611955319

# %%
print(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Max Temp</th>
#       <th>Humidity</th>
#       <th>Cloudiness</th>
#       <th>Wind Speed</th>
#       <th>Country</th>
#       <th>Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Chuy</td>
#       <td>-33.6971</td>
#       <td>-53.4616</td>
#       <td>77.14</td>
#       <td>68</td>
#       <td>2</td>
#       <td>7.61</td>
#       <td>UY</td>
#       <td>1611955477</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Rikitea</td>
#       <td>-23.1203</td>
#       <td>-134.9692</td>
#       <td>79.88</td>
#       <td>67</td>
#       <td>97</td>
#       <td>6.49</td>
#       <td>PF</td>
#       <td>1611955257</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Yellowknife</td>
#       <td>62.4560</td>
#       <td>-114.3525</td>
#       <td>-14.01</td>
# ...
